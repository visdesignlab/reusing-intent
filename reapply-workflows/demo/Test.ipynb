# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import pandas as pd
import numpy as np
import importlib
import json
import hashlib

# Link Reapply Workflow
module_path = os.path.abspath(os.path.join('..'))

sys.path = list(filter(lambda x: x!=module_path, sys.path))
sys.path.append(module_path)
# Reapply workflows is now linked
# use with 'from reapply_workflows import ......'
# %aimport reapply_workflows

from reapply_workflows import Reapply

# %%
def add_ids(data: pd.DataFrame, label: str):
    data = data.copy()

    data = data.round(5)

    # Add ids which change on row label change
    data.set_index(
        data.apply(lambda row: getUIDForString(str(row[label])), axis=1),
        inplace=True,
        verify_integrity=True,
    )

    data.reset_index(level=0, inplace=True)
    data.rename(columns={"index": "id"}, inplace=True)

    # Add iids which change on value change
    data.set_index(
        data.apply(
            lambda row: getUIDForString("_".join(row.values.astype(str))), axis=1
        ),
        inplace=True,
        verify_integrity=True,
    )

    data.reset_index(level=0, inplace=True)
    data.rename(columns={"index": "iid"}, inplace=True)

    return data

def getUIDForString(toHash: str):
  md5 = hashlib.md5(toHash.encode())
  return md5.hexdigest()

# %%
with open("./gapminder_1980.csv") as f:
  data = pd.read_csv(f)
  data = add_ids(data, 'country')
data.head()
# Out:
#                                 iid                                id  \
# 0  72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1  429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2  f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3  3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4  ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
#
#                country   tfr continent  population  life_exp     gdp    cmr
# 0              Albania  3.62    europe   2680000.0      71.7  1990.0   80.8
# 1              Algeria  6.79    africa  19200000.0      62.8  3640.0  149.0
# 2               Angola  7.50    africa   8340000.0      47.6  3180.0  238.0
# 3  Antigua and Barbuda  2.12  americas     61900.0      71.1  6370.0   44.8
# 4            Argentina  3.33  americas  27900000.0      70.1  7910.0   42.8

# %% [markdown]
# # Selections

# %%
with open("./selections.json") as f:
    wf = json.load(f)

r = Reapply()
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 124  9ac3256452dbed23b59321a91146900e  75497a22409db78dcc52c291e078bc10
# 125  b7b2832abd95dfaab237fb9314167ed3  fe07e488fe56260f45240c1c8a8882a8
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
#
#                  country   tfr continent  population  life_exp      gdp  \
# 0                Albania  3.62    europe   2680000.0      71.7   1990.0
# 1                Algeria  6.79    africa  19200000.0      62.8   3640.0
# 2                 Angola  7.50    africa   8340000.0      47.6   3180.0
# 3    Antigua and Barbuda  2.12  americas     61900.0      71.1   6370.0
# 4              Argentina  3.33  americas  27900000.0      70.1   7910.0
# ..                   ...   ...       ...         ...       ...      ...
# 124              Uruguay  2.73  americas   2920000.0      70.4   7360.0
# 125              Vanuatu  5.58      asia    116000.0      61.0   2070.0
# 126            Venezuela  4.20  americas  15200000.0      69.4  14300.0
# 127               Zambia  7.09    africa   5850000.0      56.0   1290.0
# 128             Zimbabwe  7.10    africa   7410000.0      59.7   1270.0
#
#        cmr  _Selections
# 0     80.8        False
# 1    149.0         True
# 2    238.0         True
# 3     44.8        False
# 4     42.8        False
# ..     ...          ...
# 124   39.7        False
# 125   68.7        False
# 126   43.9        False
# 127  156.0         True
# 128  107.0        False
#
# [129 rows x 10 columns]

# %% [markdown]
# # Filter

# %%
with open("./filter.json") as f:
    wf = json.load(f)

r = Reapply()
# Also a preview
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 124  9ac3256452dbed23b59321a91146900e  75497a22409db78dcc52c291e078bc10
# 125  b7b2832abd95dfaab237fb9314167ed3  fe07e488fe56260f45240c1c8a8882a8
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
#
#                  country   tfr continent  population  life_exp      gdp  \
# 0                Albania  3.62    europe   2680000.0      71.7   1990.0
# 1                Algeria  6.79    africa  19200000.0      62.8   3640.0
# 2                 Angola  7.50    africa   8340000.0      47.6   3180.0
# 3    Antigua and Barbuda  2.12  americas     61900.0      71.1   6370.0
# 4              Argentina  3.33  americas  27900000.0      70.1   7910.0
# ..                   ...   ...       ...         ...       ...      ...
# 124              Uruguay  2.73  americas   2920000.0      70.4   7360.0
# 125              Vanuatu  5.58      asia    116000.0      61.0   2070.0
# 126            Venezuela  4.20  americas  15200000.0      69.4  14300.0
# 127               Zambia  7.09    africa   5850000.0      56.0   1290.0
# 128             Zimbabwe  7.10    africa   7410000.0      59.7   1270.0
#
#        cmr  Filtered
# 0     80.8      True
# 1    149.0     False
# 2    238.0     False
# 3     44.8      True
# 4     42.8      True
# ..     ...       ...
# 124   39.7      True
# 125   68.7      True
# 126   43.9      True
# 127  156.0     False
# 128  107.0      True
#
# [129 rows x 10 columns]

# %% [markdown]
# # Label

# %%
with open("./label.json") as f:
    wf = json.load(f)

r = Reapply()
# Empty string
# Showing multiple labels? -> 
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 124  9ac3256452dbed23b59321a91146900e  75497a22409db78dcc52c291e078bc10
# 125  b7b2832abd95dfaab237fb9314167ed3  fe07e488fe56260f45240c1c8a8882a8
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
#
#                  country   tfr continent  population  life_exp      gdp  \
# 0                Albania  3.62    europe   2680000.0      71.7   1990.0
# 1                Algeria  6.79    africa  19200000.0      62.8   3640.0
# 2                 Angola  7.50    africa   8340000.0      47.6   3180.0
# 3    Antigua and Barbuda  2.12  americas     61900.0      71.1   6370.0
# 4              Argentina  3.33  americas  27900000.0      70.1   7910.0
# ..                   ...   ...       ...         ...       ...      ...
# 124              Uruguay  2.73  americas   2920000.0      70.4   7360.0
# 125              Vanuatu  5.58      asia    116000.0      61.0   2070.0
# 126            Venezuela  4.20  americas  15200000.0      69.4  14300.0
# 127               Zambia  7.09    africa   5850000.0      56.0   1290.0
# 128             Zimbabwe  7.10    africa   7410000.0      59.7   1270.0
#
#        cmr        Labels
# 0     80.8    Unassigned
# 1    149.0  test_label_1
# 2    238.0  test_label_1
# 3     44.8    Unassigned
# 4     42.8  test_label_2
# ..     ...           ...
# 124   39.7  test_label_2
# 125   68.7    Unassigned
# 126   43.9    Unassigned
# 127  156.0  test_label_1
# 128  107.0    Unassigned
#
# [129 rows x 10 columns]

# %% [markdown]
# # Categorize

# %%
with open("./categorize.json") as f:
    wf = json.load(f)

r = Reapply()
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 124  9ac3256452dbed23b59321a91146900e  75497a22409db78dcc52c291e078bc10
# 125  b7b2832abd95dfaab237fb9314167ed3  fe07e488fe56260f45240c1c8a8882a8
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
#
#                  country   tfr continent  population  life_exp      gdp  \
# 0                Albania  3.62    europe   2680000.0      71.7   1990.0
# 1                Algeria  6.79    africa  19200000.0      62.8   3640.0
# 2                 Angola  7.50    africa   8340000.0      47.6   3180.0
# 3    Antigua and Barbuda  2.12  americas     61900.0      71.1   6370.0
# 4              Argentina  3.33  americas  27900000.0      70.1   7910.0
# ..                   ...   ...       ...         ...       ...      ...
# 124              Uruguay  2.73  americas   2920000.0      70.4   7360.0
# 125              Vanuatu  5.58      asia    116000.0      61.0   2070.0
# 126            Venezuela  4.20  americas  15200000.0      69.4  14300.0
# 127               Zambia  7.09    africa   5850000.0      56.0   1290.0
# 128             Zimbabwe  7.10    africa   7410000.0      59.7   1270.0
#
#        cmr Test Category
# 0     80.8          None
# 1    149.0      Option 1
# 2    238.0      Option 1
# 3     44.8          None
# 4     42.8      Option 2
# ..     ...           ...
# 124   39.7      Option 2
# 125   68.7          None
# 126   43.9          None
# 127  156.0      Option 1
# 128  107.0          None
#
# [129 rows x 10 columns]

# %%
with open("./categorize 2.json") as f:
    wf = json.load(f)

r = Reapply()
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 124  9ac3256452dbed23b59321a91146900e  75497a22409db78dcc52c291e078bc10
# 125  b7b2832abd95dfaab237fb9314167ed3  fe07e488fe56260f45240c1c8a8882a8
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
#
#                  country   tfr continent  population  life_exp      gdp  \
# 0                Albania  3.62    europe   2680000.0      71.7   1990.0
# 1                Algeria  6.79    africa  19200000.0      62.8   3640.0
# 2                 Angola  7.50    africa   8340000.0      47.6   3180.0
# 3    Antigua and Barbuda  2.12  americas     61900.0      71.1   6370.0
# 4              Argentina  3.33  americas  27900000.0      70.1   7910.0
# ..                   ...   ...       ...         ...       ...      ...
# 124              Uruguay  2.73  americas   2920000.0      70.4   7360.0
# 125              Vanuatu  5.58      asia    116000.0      61.0   2070.0
# 126            Venezuela  4.20  americas  15200000.0      69.4  14300.0
# 127               Zambia  7.09    africa   5850000.0      56.0   1290.0
# 128             Zimbabwe  7.10    africa   7410000.0      59.7   1270.0
#
#        cmr Test Category    Test Category 2
# 0     80.8          None               None
# 1    149.0      Option 1               None
# 2    238.0      Option 1               None
# 3     44.8          None               None
# 4     42.8          None  Option Category 2
# ..     ...           ...                ...
# 124   39.7          None  Option Category 2
# 125   68.7          None               None
# 126   43.9          None               None
# 127  156.0      Option 1               None
# 128  107.0          None               None
#
# [129 rows x 11 columns]

# %% [markdown]
# # Aggregation

# %%
with open("./agg.json") as f:
    wf = json.load(f)

r = Reapply()
# Add aggregate to ids
# Take a label for aggregate
# No need for showing aggregate by info for columns
recs = r.apply(wf['interactions'], data)
recs[-1].df
# Out:
#                                   iid                                id  \
# 0    72446c56b549652b274c6e9181558711  c420ddff824a5c0eec70dd23d62496bc
# 1    429079562aaef4ceb00dc9aa90df68e4  575b9408b6daa2ddcefbcf6d81c9b4c9
# 2    f17777056433e867b34a50ddbbe6bd43  232bf11cb81bcdb269f76a08fde8b947
# 3    3e0b86945744fcc37eb53c67f42f5521  f7e68bf0791888ebcd5bfc62e022aa83
# 4    ac1e36a436482b405a8621aae3801634  3536be57ce0713954e454ae6c53ec023
# ..                                ...                               ...
# 126  57e57d86a993a865423dfa433bd7b2a6  e95294b730f61c8175550ec244bfcb50
# 127  fc6ba0e72ab596b851ba1026d4ebefd7  b0aa0804e676a38255af4fd70236af7c
# 128  ded8203952f9e799b681036a7f243cf1  9d5116a2451bc98c2b46b93acbc1b4f0
# 0                  agg25244154 (Mean)                agg25244154 (Mean)
# 0                    agg3888383 (Sum)                  agg3888383 (Sum)
#
#                  country         tfr           continent    population  \
# 0                Albania    3.620000              europe  2.680000e+06
# 1                Algeria    6.790000              africa  1.920000e+07
# 2                 Angola    7.500000              africa  8.340000e+06
# 3    Antigua and Barbuda    2.120000            americas  6.190000e+04
# 4              Argentina    3.330000            americas  2.790000e+07
# ..                   ...         ...                 ...           ...
# 126            Venezuela    4.200000            americas  1.520000e+07
# 127               Zambia    7.090000              africa  5.850000e+06
# 128             Zimbabwe    7.100000              africa  7.410000e+06
# 0     agg25244154 (Mean)    4.649457  agg25244154 (Mean)  2.986460e+07
# 0       agg3888383 (Sum)  599.780000    agg3888383 (Sum)  3.852533e+09
#
#         life_exp           gdp           cmr
# 0      71.700000  1.990000e+03     80.800000
# 1      62.800000  3.640000e+03    149.000000
# 2      47.600000  3.180000e+03    238.000000
# 3      71.100000  6.370000e+03     44.800000
# 4      70.100000  7.910000e+03     42.800000
# ..           ...           ...           ...
# 126    69.400000  1.430000e+04     43.900000
# 127    56.000000  1.290000e+03    156.000000
# 128    59.700000  1.270000e+03    107.000000
# 0      64.037209  9.635783e+03     97.248527
# 0    8260.800000  1.243016e+06  12545.060000
#
# [131 rows x 9 columns]

# %%
# Talk to Zach
# Focus also on writing
